# %%
##############INSERT FILE NAME HERE###################
fileName = "CommandList_PMID-_EXPID--_..csv"

#IMPORTING LIBRARIES---------
import os
import opentrons.execute
sourceLoc = "C:\\Users\\Sebastian\\Desktop\\MSc Leiden 2nd Year\\##LabAst Works\\ot2"
#sourceLoc = '/var/lib/jupyter/notebooks/User Inputs'
os.chdir(sourceLoc)
from OT2_ControllerLib import *
from opentrons import simulate

#READING COMMAND LIST----------
save_folder = "C:\\Users\\Sebastian\\Desktop\\MSc Leiden 2nd Year\\##LabAst Works\\ot2"
#save_folder = '/var/lib/jupyter/notebooks/User Inputs'
os.chdir(save_folder)
amtList, cmdList, deckMap = ReadCSV_Dat(fileName)

########### SIMULATE ############
#define protocol
bep = simulate.get_protocol_api('2.3')

#Operation
bep.home()
try:
    run(bep, cmdList, deckMap, amtList) 
    print("\n=====================================================\nSIMULATION COMPLETE -- EVERYTHING SEEMS OKAY (so far)\n=====================================================")
except:
    print("Run terminated prematurely (see the last printed step)")

#prompt decision
continue_dec = input("Continue run? (Y/N)")

########### EXECUTE ############
if(continue_dec == "Y" or continue_dec=="y"):
    #define protocol
    bep = opentrons.execute.get_protocol_api('2.3')

    #Operation
    bep.home()
    run(bep, cmdList, deckMap, amtList)
# Out:
# C:\Users\Sebastian\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\Sebastian\.opentrons\robot_settings.json not found. Loading defaults
# ['labware_11' 'A1' 'labware_8' 'B2, C2, D2, E2, F2, G2' '1440' '0' '1'
#  'solvent distribution for first stock dilution in deep wells']
# ['labware_9' 'A1' 'labware_8' 'B2' '160' '160' '2'
#  'First dilution to deep wells']
# ['labware_9' 'A1' 'labware_8' 'C2' '160' '160' '3'
#  'First dilution to deep wells']
# ['labware_9' 'A1' 'labware_8' 'D2' '160' '160' '4'
#  'First dilution to deep wells']
# ['labware_9' 'A1' 'labware_8' 'E2' '160' '160' '5'
#  'First dilution to deep wells']
# ['labware_9' 'A1' 'labware_8' 'F2' '160' '160' '6'
#  'First dilution to deep wells']
# ['labware_9' 'A1' 'labware_8' 'G2' '160' '160' '7'
#  'First dilution to deep wells']
# ['labware_11' 'A2' 'labware_8'
#  'B3, C3, D3, E3, F3, G3, B4, C4, D4, E4, F4, G4, B5, C5, D5, E5, F5, G5, B6, C6, D6, E6, F6, G6, B7, C7, D7, E7, F7, G7, B8, C8, D8, E8, F8, G8, B9, C9, D9, E9, F9, G9, B10, C10, D10, E10, F10, G10, B11, C11, D11, E11, F11, G11'
#  '800' '0' '8' 'solvent distribution for serial dilution']
# ['labware_11' 'A3' 'labware_8' 'B11, C11, D11, E11, F11, G11' '800' '0'
#  '9' 'solvent distribution for serial dilution']
# ['labware_8' 'A2, B2, C2, D2, E2, F2, G2, H2' 'labware_8'
#  'A3, B3, C3, D3, E3, F3, G3, H3' '800' '800' '10'
#  'Serial dilution with MC pipette']
# ['labware_8' 'A3, B3, C3, D3, E3, F3, G3, H3' 'labware_8'
#  'A4, B4, C4, D4, E4, F4, G4, H4' '800' '800' '18'
#  'Serial dilution with MC pipette']
# ['labware_8' 'A4, B4, C4, D4, E4, F4, G4, H4' 'labware_8'
#  'A5, B5, C5, D5, E5, F5, G5, H5' '800' '800' '26'
#  'Serial dilution with MC pipette']
# ['labware_8' 'A5, B5, C5, D5, E5, F5, G5, H5' 'labware_8'
#  'A6, B6, C6, D6, E6, F6, G6, H6' '800' '800' '34'
#  'Serial dilution with MC pipette']
# ['labware_8' 'A6, B6, C6, D6, E6, F6, G6, H6' 'labware_8'
#  'A7, B7, C7, D7, E7, F7, G7, H7' '800' '800' '42'
#  'Serial dilution with MC pipette']
# ['labware_8' 'A7, B7, C7, D7, E7, F7, G7, H7' 'labware_8'
#  'A8, B8, C8, D8, E8, F8, G8, H8' '800' '800' '50'
#  'Serial dilution with MC pipette']
# ['labware_8' 'A8, B8, C8, D8, E8, F8, G8, H8' 'labware_8'
#  'A9, B9, C9, D9, E9, F9, G9, H9' '800' '800' '58'
#  'Serial dilution with MC pipette']
# ['labware_8' 'A9, B9, C9, D9, E9, F9, G9, H9' 'labware_8'
#  'A10, B10, C10, D10, E10, F10, G10, H10' '800' '800' '66'
#  'Serial dilution with MC pipette']
# ['labware_11' 'B1' 'labware_8'
#  'A1, B1, C1, D1, E1, F1, G1, H1, A2, H2, A3, H3, A4, H4, A5, H5, A6, H6, A7, H7, A8, H8, A9, H9, A10, H10, A11, H11, A12, B12, C12, D12, E12, F12, G12, H12'
#  '1300' '0' '67' 'Filling outer wells of plate in labware_8']
# ['labware_8' 'A1, B1, C1, D1, E1, F1, G1, H1' 'labware_1'
#  'A1, B1, C1, D1, E1, F1, G1, H1' '200' '200' '75'
#  'Distributing column 1 to labware_1']
# ['labware_8' 'A1, B1, C1, D1, E1, F1, G1, H1' 'labware_2'
#  'A1, B1, C1, D1, E1, F1, G1, H1' '200' '200' '75'
#  'Distributing column 1 to labware_2']
# ['labware_8' 'A1, B1, C1, D1, E1, F1, G1, H1' 'labware_4'
#  'A1, B1, C1, D1, E1, F1, G1, H1' '200' '200' '75'
#  'Distributing column 1 to labware_4']
# ['labware_8' 'A1, B1, C1, D1, E1, F1, G1, H1' 'labware_5'
#  'A1, B1, C1, D1, E1, F1, G1, H1' '200' '200' '75'
#  'Distributing column 1 to labware_5']
# ['labware_8' 'A1, B1, C1, D1, E1, F1, G1, H1' 'labware_6'
#  'A1, B1, C1, D1, E1, F1, G1, H1' '200' '200' '75'
#  'Distributing column 1 to labware_6']
# ['labware_8' 'A2, B2, C2, D2, E2, F2, G2, H2' 'labware_1'
#  'A2, B2, C2, D2, E2, F2, G2, H2' '100' '100' '83'
#  'Distributing column 2 to labware_1']
# ['labware_8' 'A2, B2, C2, D2, E2, F2, G2, H2' 'labware_2'
#  'A2, B2, C2, D2, E2, F2, G2, H2' '100' '100' '83'
#  'Distributing column 2 to labware_2']
# ['labware_8' 'A2, B2, C2, D2, E2, F2, G2, H2' 'labware_4'
#  'A2, B2, C2, D2, E2, F2, G2, H2' '100' '100' '83'
#  'Distributing column 2 to labware_4']
# ['labware_8' 'A2, B2, C2, D2, E2, F2, G2, H2' 'labware_5'
#  'A2, B2, C2, D2, E2, F2, G2, H2' '100' '100' '83'
#  'Distributing column 2 to labware_5']
# ['labware_8' 'A2, B2, C2, D2, E2, F2, G2, H2' 'labware_6'
#  'A2, B2, C2, D2, E2, F2, G2, H2' '100' '100' '83'
#  'Distributing column 2 to labware_6']
# ['labware_8' 'A3, B3, C3, D3, E3, F3, G3, H3' 'labware_1'
#  'A3, B3, C3, D3, E3, F3, G3, H3' '100' '100' '91'
#  'Distributing column 3 to labware_1']
# ['labware_8' 'A3, B3, C3, D3, E3, F3, G3, H3' 'labware_2'
#  'A3, B3, C3, D3, E3, F3, G3, H3' '100' '100' '91'
#  'Distributing column 3 to labware_2']
# ['labware_8' 'A3, B3, C3, D3, E3, F3, G3, H3' 'labware_4'
#  'A3, B3, C3, D3, E3, F3, G3, H3' '100' '100' '91'
#  'Distributing column 3 to labware_4']
# ['labware_8' 'A3, B3, C3, D3, E3, F3, G3, H3' 'labware_5'
#  'A3, B3, C3, D3, E3, F3, G3, H3' '100' '100' '91'
#  'Distributing column 3 to labware_5']
# ['labware_8' 'A3, B3, C3, D3, E3, F3, G3, H3' 'labware_6'
#  'A3, B3, C3, D3, E3, F3, G3, H3' '100' '100' '91'
#  'Distributing column 3 to labware_6']
# ['labware_8' 'A4, B4, C4, D4, E4, F4, G4, H4' 'labware_1'
#  'A4, B4, C4, D4, E4, F4, G4, H4' '100' '100' '99'
#  'Distributing column 4 to labware_1']
# ['labware_8' 'A4, B4, C4, D4, E4, F4, G4, H4' 'labware_2'
#  'A4, B4, C4, D4, E4, F4, G4, H4' '100' '100' '99'
#  'Distributing column 4 to labware_2']
# ['labware_8' 'A4, B4, C4, D4, E4, F4, G4, H4' 'labware_4'
#  'A4, B4, C4, D4, E4, F4, G4, H4' '100' '100' '99'
#  'Distributing column 4 to labware_4']
# ['labware_8' 'A4, B4, C4, D4, E4, F4, G4, H4' 'labware_5'
#  'A4, B4, C4, D4, E4, F4, G4, H4' '100' '100' '99'
#  'Distributing column 4 to labware_5']
# ['labware_8' 'A4, B4, C4, D4, E4, F4, G4, H4' 'labware_6'
#  'A4, B4, C4, D4, E4, F4, G4, H4' '100' '100' '99'
#  'Distributing column 4 to labware_6']
# ['labware_8' 'A5, B5, C5, D5, E5, F5, G5, H5' 'labware_1'
#  'A5, B5, C5, D5, E5, F5, G5, H5' '100' '100' '107'
#  'Distributing column 5 to labware_1']
# ['labware_8' 'A5, B5, C5, D5, E5, F5, G5, H5' 'labware_2'
#  'A5, B5, C5, D5, E5, F5, G5, H5' '100' '100' '107'
#  'Distributing column 5 to labware_2']
# ['labware_8' 'A5, B5, C5, D5, E5, F5, G5, H5' 'labware_4'
#  'A5, B5, C5, D5, E5, F5, G5, H5' '100' '100' '107'
#  'Distributing column 5 to labware_4']
# ['labware_8' 'A5, B5, C5, D5, E5, F5, G5, H5' 'labware_5'
#  'A5, B5, C5, D5, E5, F5, G5, H5' '100' '100' '107'
#  'Distributing column 5 to labware_5']
# ['labware_8' 'A5, B5, C5, D5, E5, F5, G5, H5' 'labware_6'
#  'A5, B5, C5, D5, E5, F5, G5, H5' '100' '100' '107'
#  'Distributing column 5 to labware_6']
# ['labware_8' 'A6, B6, C6, D6, E6, F6, G6, H6' 'labware_1'
#  'A6, B6, C6, D6, E6, F6, G6, H6' '100' '100' '115'
#  'Distributing column 6 to labware_1']
# ['labware_8' 'A6, B6, C6, D6, E6, F6, G6, H6' 'labware_2'
#  'A6, B6, C6, D6, E6, F6, G6, H6' '100' '100' '115'
#  'Distributing column 6 to labware_2']
# ['labware_8' 'A6, B6, C6, D6, E6, F6, G6, H6' 'labware_4'
#  'A6, B6, C6, D6, E6, F6, G6, H6' '100' '100' '115'
#  'Distributing column 6 to labware_4']
# ['labware_8' 'A6, B6, C6, D6, E6, F6, G6, H6' 'labware_5'
#  'A6, B6, C6, D6, E6, F6, G6, H6' '100' '100' '115'
#  'Distributing column 6 to labware_5']
# ['labware_8' 'A6, B6, C6, D6, E6, F6, G6, H6' 'labware_6'
#  'A6, B6, C6, D6, E6, F6, G6, H6' '100' '100' '115'
#  'Distributing column 6 to labware_6']
# ['labware_8' 'A7, B7, C7, D7, E7, F7, G7, H7' 'labware_1'
#  'A7, B7, C7, D7, E7, F7, G7, H7' '100' '100' '123'
#  'Distributing column 7 to labware_1']
# ['labware_8' 'A7, B7, C7, D7, E7, F7, G7, H7' 'labware_2'
#  'A7, B7, C7, D7, E7, F7, G7, H7' '100' '100' '123'
#  'Distributing column 7 to labware_2']
# ['labware_8' 'A7, B7, C7, D7, E7, F7, G7, H7' 'labware_4'
#  'A7, B7, C7, D7, E7, F7, G7, H7' '100' '100' '123'
#  'Distributing column 7 to labware_4']
# ['labware_8' 'A7, B7, C7, D7, E7, F7, G7, H7' 'labware_5'
#  'A7, B7, C7, D7, E7, F7, G7, H7' '100' '100' '123'
#  'Distributing column 7 to labware_5']
# ['labware_8' 'A7, B7, C7, D7, E7, F7, G7, H7' 'labware_6'
#  'A7, B7, C7, D7, E7, F7, G7, H7' '100' '100' '123'
#  'Distributing column 7 to labware_6']
# ['labware_8' 'A8, B8, C8, D8, E8, F8, G8, H8' 'labware_1'
#  'A8, B8, C8, D8, E8, F8, G8, H8' '100' '100' '131'
#  'Distributing column 8 to labware_1']
# ['labware_8' 'A8, B8, C8, D8, E8, F8, G8, H8' 'labware_2'
#  'A8, B8, C8, D8, E8, F8, G8, H8' '100' '100' '131'
#  'Distributing column 8 to labware_2']
# ['labware_8' 'A8, B8, C8, D8, E8, F8, G8, H8' 'labware_4'
#  'A8, B8, C8, D8, E8, F8, G8, H8' '100' '100' '131'
#  'Distributing column 8 to labware_4']
# ['labware_8' 'A8, B8, C8, D8, E8, F8, G8, H8' 'labware_5'
#  'A8, B8, C8, D8, E8, F8, G8, H8' '100' '100' '131'
#  'Distributing column 8 to labware_5']
# ['labware_8' 'A8, B8, C8, D8, E8, F8, G8, H8' 'labware_6'
#  'A8, B8, C8, D8, E8, F8, G8, H8' '100' '100' '131'
#  'Distributing column 8 to labware_6']
# ['labware_8' 'A9, B9, C9, D9, E9, F9, G9, H9' 'labware_1'
#  'A9, B9, C9, D9, E9, F9, G9, H9' '100' '100' '139'
#  'Distributing column 9 to labware_1']
# ['labware_8' 'A9, B9, C9, D9, E9, F9, G9, H9' 'labware_2'
#  'A9, B9, C9, D9, E9, F9, G9, H9' '100' '100' '139'
#  'Distributing column 9 to labware_2']
# ['labware_8' 'A9, B9, C9, D9, E9, F9, G9, H9' 'labware_4'
#  'A9, B9, C9, D9, E9, F9, G9, H9' '100' '100' '139'
#  'Distributing column 9 to labware_4']
# ['labware_8' 'A9, B9, C9, D9, E9, F9, G9, H9' 'labware_5'
#  'A9, B9, C9, D9, E9, F9, G9, H9' '100' '100' '139'
#  'Distributing column 9 to labware_5']
# ['labware_8' 'A9, B9, C9, D9, E9, F9, G9, H9' 'labware_6'
#  'A9, B9, C9, D9, E9, F9, G9, H9' '100' '100' '139'
#  'Distributing column 9 to labware_6']
# ['labware_8' 'A10, B10, C10, D10, E10, F10, G10, H10' 'labware_1'
#  'A10, B10, C10, D10, E10, F10, G10, H10' '100' '100' '147'
#  'Distributing column 10 to labware_1']
# ['labware_8' 'A10, B10, C10, D10, E10, F10, G10, H10' 'labware_2'
#  'A10, B10, C10, D10, E10, F10, G10, H10' '100' '100' '147'
#  'Distributing column 10 to labware_2']
# ['labware_8' 'A10, B10, C10, D10, E10, F10, G10, H10' 'labware_4'
#  'A10, B10, C10, D10, E10, F10, G10, H10' '100' '100' '147'
#  'Distributing column 10 to labware_4']
# ['labware_8' 'A10, B10, C10, D10, E10, F10, G10, H10' 'labware_5'
#  'A10, B10, C10, D10, E10, F10, G10, H10' '100' '100' '147'
#  'Distributing column 10 to labware_5']
# ['labware_8' 'A10, B10, C10, D10, E10, F10, G10, H10' 'labware_6'
#  'A10, B10, C10, D10, E10, F10, G10, H10' '100' '100' '147'
#  'Distributing column 10 to labware_6']
# ['labware_8' 'A11, B11, C11, D11, E11, F11, G11, H11' 'labware_1'
#  'A11, B11, C11, D11, E11, F11, G11, H11' '100' '100' '155'
#  'Distributing column 11 to labware_1']
# ['labware_8' 'A11, B11, C11, D11, E11, F11, G11, H11' 'labware_2'
#  'A11, B11, C11, D11, E11, F11, G11, H11' '100' '100' '155'
#  'Distributing column 11 to labware_2']
# ['labware_8' 'A11, B11, C11, D11, E11, F11, G11, H11' 'labware_4'
#  'A11, B11, C11, D11, E11, F11, G11, H11' '100' '100' '155'
#  'Distributing column 11 to labware_4']
# ['labware_8' 'A11, B11, C11, D11, E11, F11, G11, H11' 'labware_5'
#  'A11, B11, C11, D11, E11, F11, G11, H11' '100' '100' '155'
#  'Distributing column 11 to labware_5']
# ['labware_8' 'A11, B11, C11, D11, E11, F11, G11, H11' 'labware_6'
#  'A11, B11, C11, D11, E11, F11, G11, H11' '100' '100' '155'
#  'Distributing column 11 to labware_6']
# ['labware_8' 'A12, B12, C12, D12, E12, F12, G12, H12' 'labware_1'
#  'A12, B12, C12, D12, E12, F12, G12, H12' '200' '200' '163'
#  'Distributing column 12 to labware_1']
# ['labware_8' 'A12, B12, C12, D12, E12, F12, G12, H12' 'labware_2'
#  'A12, B12, C12, D12, E12, F12, G12, H12' '200' '200' '163'
#  'Distributing column 12 to labware_2']
# ['labware_8' 'A12, B12, C12, D12, E12, F12, G12, H12' 'labware_4'
#  'A12, B12, C12, D12, E12, F12, G12, H12' '200' '200' '163'
#  'Distributing column 12 to labware_4']
# ['labware_8' 'A12, B12, C12, D12, E12, F12, G12, H12' 'labware_5'
#  'A12, B12, C12, D12, E12, F12, G12, H12' '200' '200' '163'
#  'Distributing column 12 to labware_5']
# ['labware_8' 'A12, B12, C12, D12, E12, F12, G12, H12' 'labware_6'
#  'A12, B12, C12, D12, E12, F12, G12, H12' '200' '200' '163'
#  'Distributing column 12 to labware_6']
#
# =====================================================
# SIMULATION COMPLETE -- EVERYTHING SEEMS OKAY (so far)
# =====================================================
# Continue run? (Y/N)N
# This is intended to run on a robot, and while it can connect to a smoothie via a usb/serial adapter unexpected things using gpios (such as smoothie reset or light management) will fail. If you are seeing this message and you are running on a robot, you need to set the RUNNING_ON_PI environmental variable to 1.
# C:\Users\Sebastian\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\Sebastian\.opentrons\robot_settings.json not found. Loading defaults
# Failed to initialize character device, will not be able to control gpios (lights, button, smoothiekill, smoothie reset). If you need to control gpios, first stop the robot server with systemctl stop opentrons-robot-server. Until you restart the server with systemctl start opentrons-robot-server, you will be unable to control the robot using the Opentrons app.
# Failed to initiate aionotify, cannot watch modules or door, likely because not running on linux
# Motor driver could not connect, reprogramming if possible
# Traceback (most recent call last):
#   File "C:\Users\Sebastian\anaconda3\lib\site-packages\opentrons\hardware_control\api.py", line 142, in build_hardware_controller
#     await backend.connect(port)
#   File "C:\Users\Sebastian\anaconda3\lib\site-packages\opentrons\hardware_control\controller.py", line 219, in connect
#     self._smoothie_driver.connect(port)
#   File "C:\Users\Sebastian\anaconda3\lib\site-packages\opentrons\drivers\smoothie_drivers\driver_3_0.py", line 580, in connect
#     self._connect_to_port(port)
#   File "C:\Users\Sebastian\anaconda3\lib\site-packages\opentrons\drivers\smoothie_drivers\driver_3_0.py", line 600, in _connect_to_port
#     baudrate=self._config.serial_speed
#   File "C:\Users\Sebastian\anaconda3\lib\site-packages\opentrons\drivers\serial_communication.py", line 127, in connect
#     port = get_ports_by_name(device_name=device_name)[0]
# IndexError: list index out of range
# Motor controller could not be connected and no firmware was provided for (re)programming
# Exception in Thread Manager build
# Traceback (most recent call last):
#   File "C:\Users\Sebastian\anaconda3\lib\site-packages\opentrons\hardware_control\thread_manager.py", line 150, in _build_and_start_loop
#     **kwargs))
#   File "C:\Users\Sebastian\anaconda3\lib\asyncio\base_events.py", line 583, in run_until_complete
#     return future.result()
#   File "C:\Users\Sebastian\anaconda3\lib\site-packages\opentrons\hardware_control\api.py", line 159, in build_hardware_controller
#     raise RuntimeError(msg)
# RuntimeError: Motor controller could not be connected and no firmware was provided for (re)programming
# ---------------------------------------------------------------------------
# ThreadManagerException                    Traceback (most recent call last)
# <ipython-input-2-0751eaa68bea> in <module>
#      34 ########### SIMULATE ############
#      35 #define protocol
# ---> 36 bep = opentrons.execute.get_protocol_api('2.3')
#      37
#      38 #Operation
#
# ~\anaconda3\lib\site-packages\opentrons\execute.py in get_protocol_api(version, bundled_labware, bundled_data, extra_labware)
#      88         # you can't control the loop from inside. If we update to
#      89         # IPython 7 we can avoid this, but for now we can't
# ---> 90         _THREAD_MANAGED_HW = ThreadManager(API.build_hardware_controller)
#      91     if isinstance(version, str):
#      92         checked_version = version_from_string(version)
#
# ~\anaconda3\lib\site-packages\opentrons\hardware_control\thread_manager.py in __init__(self, builder, *args, **kwargs)
#     126         thread.start()
#     127         if blocking:
# --> 128             object.__getattribute__(self, 'managed_thread_ready_blocking')()
#     129
#     130     def managed_thread_ready_blocking(self):
#
# ~\anaconda3\lib\site-packages\opentrons\hardware_control\thread_manager.py in managed_thread_ready_blocking(self)
#     131         object.__getattribute__(self, '_is_running').wait()
#     132         if not object.__getattribute__(self, 'managed_obj'):
# --> 133             raise ThreadManagerException("Failed to create Managed Object")
#     134
#     135     async def managed_thread_ready_async(self):
#
# ThreadManagerException: Failed to create Managed Object
