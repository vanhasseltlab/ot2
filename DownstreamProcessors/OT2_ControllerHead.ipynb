# %%
#EXECUTE
exec(compile(open("C:\\Users\\Sebastian\\Desktop\\MSc Leiden 2nd Year\\##LabAst Works\\ot2\\DownstreamProcessors\\MainExec.py", "rb").read(), "SeparatedCommaned.py", 'exec'))

#exec(compile(open("/var/lib/jupyter/notebooks/MainExec.py", "rb").read(), "SeparatedCommaned.py", 'exec'))
# Out:
# File Name: CommandList_PMID-_EXPID--_. (3).csv
# C:\Users\Sebastian\.opentrons\deck_calibration.json not found. Loading defaults
# C:\Users\Sebastian\.opentrons\robot_settings.json not found. Loading defaults
# ['labware_6' 'A1' 'labware_5' 'A1' '3350' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'A2' '1675' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'A3' '2512.5' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'A4' '2931.25' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'A5' '3140.625' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'B1' '3245.3125' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'B2' '3297.65625' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'B3' '3323.828125' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'B4' '3336.9140625' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'B5' '3343.45703125' '0' '1'
#  'Initial solvent distribution']
# ['labware_6' 'A1' 'labware_5' 'C1' '6024.111328125' '0' '1'
#  'Initial solvent distribution']
# ['labware_9' 'A1' 'labware_5' 'C1' '669.345703125' '669.345703125' '2'
#  'Initial stock dilution']
# MIXING
# MIXING
# MIXING
# ['labware_5' 'C1' 'labware_5' 'B5' '3343.45703125' '3343.45703125' '3'
#  'Serially diluting to  AZT 256 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'B5' 'labware_5' 'B4' '3336.9140625' '3336.9140625' '4'
#  'Serially diluting to  AZT 128 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'B4' 'labware_5' 'B3' '3323.828125' '3323.828125' '5'
#  'Serially diluting to  AZT 64 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'B3' 'labware_5' 'B2' '3297.65625' '3297.65625' '6'
#  'Serially diluting to  AZT 32 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'B2' 'labware_5' 'B1' '3245.3125' '3245.3125' '7'
#  'Serially diluting to  AZT 16 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'B1' 'labware_5' 'A5' '3140.625' '3140.625' '8'
#  'Serially diluting to  AZT 8 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'A5' 'labware_5' 'A4' '2931.25' '2931.25' '9'
#  'Serially diluting to  AZT 4 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'A4' 'labware_5' 'A3' '2512.5' '2512.5' '10'
#  'Serially diluting to  AZT 2 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'A3' 'labware_5' 'A2' '1675' '1675' '11'
#  'Serially diluting to  AZT 1 MED_A']
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# MIXING
# ['labware_5' 'A1' 'labware_1' 'A11, B11, C11, D11, E11, F11, G11, H11'
#  '100' '0' '12' 'Distributing  AZT 0 MED_A']
# ['labware_5' 'A1' 'labware_2' 'A11, B11, C11, D11, E11, F11, G11, H11'
#  '100' '0' '12' 'Distributing  AZT 0 MED_A']
# ['labware_5' 'A1' 'labware_3' 'A11, B11, C11, D11, E11, F11, G11, H11'
#  '100' '0' '12' 'Distributing  AZT 0 MED_A']
# ['labware_5' 'A1' 'labware_4' 'A11, B11, C11, D11, E11, F11, G11, H11'
#  '100' '0' '12' 'Distributing  AZT 0 MED_A']
# ['labware_5' 'A2' 'labware_1' 'A10, B10, C10, D10, E10, F10, G10, H10'
#  '100' '0' '13' 'Distributing  AZT 1 MED_A']
# ['labware_5' 'A2' 'labware_2' 'A10, B10, C10, D10, E10, F10, G10, H10'
#  '100' '0' '13' 'Distributing  AZT 1 MED_A']
# ['labware_5' 'A2' 'labware_3' 'A10, B10, C10, D10, E10, F10, G10, H10'
#  '100' '0' '13' 'Distributing  AZT 1 MED_A']
# ['labware_5' 'A2' 'labware_4' 'A10, B10, C10, D10, E10, F10, G10, H10'
#  '100' '0' '13' 'Distributing  AZT 1 MED_A']
# ['labware_5' 'A3' 'labware_1' 'A9, B9, C9, D9, E9, F9, G9, H9' '100' '0'
#  '14' 'Distributing  AZT 2 MED_A']
# ['labware_5' 'A3' 'labware_2' 'A9, B9, C9, D9, E9, F9, G9, H9' '100' '0'
#  '14' 'Distributing  AZT 2 MED_A']
# ['labware_5' 'A3' 'labware_3' 'A9, B9, C9, D9, E9, F9, G9, H9' '100' '0'
#  '14' 'Distributing  AZT 2 MED_A']
# ['labware_5' 'A3' 'labware_4' 'A9, B9, C9, D9, E9, F9, G9, H9' '100' '0'
#  '14' 'Distributing  AZT 2 MED_A']
# ['labware_5' 'A4' 'labware_1' 'A8, B8, C8, D8, E8, F8, G8, H8' '100' '0'
#  '15' 'Distributing  AZT 4 MED_A']
# ['labware_5' 'A4' 'labware_2' 'A8, B8, C8, D8, E8, F8, G8, H8' '100' '0'
#  '15' 'Distributing  AZT 4 MED_A']
# ['labware_5' 'A4' 'labware_3' 'A8, B8, C8, D8, E8, F8, G8, H8' '100' '0'
#  '15' 'Distributing  AZT 4 MED_A']
# ['labware_5' 'A4' 'labware_4' 'A8, B8, C8, D8, E8, F8, G8, H8' '100' '0'
#  '15' 'Distributing  AZT 4 MED_A']
# ['labware_5' 'A5' 'labware_1' 'A7, B7, C7, D7, E7, F7, G7, H7' '100' '0'
#  '16' 'Distributing  AZT 8 MED_A']
# ['labware_5' 'A5' 'labware_2' 'A7, B7, C7, D7, E7, F7, G7, H7' '100' '0'
#  '16' 'Distributing  AZT 8 MED_A']
# ['labware_5' 'A5' 'labware_3' 'A7, B7, C7, D7, E7, F7, G7, H7' '100' '0'
#  '16' 'Distributing  AZT 8 MED_A']
# ['labware_5' 'A5' 'labware_4' 'A7, B7, C7, D7, E7, F7, G7, H7' '100' '0'
#  '16' 'Distributing  AZT 8 MED_A']
# ['labware_5' 'B1' 'labware_1' 'A6, B6, C6, D6, E6, F6, G6, H6' '100' '0'
#  '17' 'Distributing  AZT 16 MED_A']
# ['labware_5' 'B1' 'labware_2' 'A6, B6, C6, D6, E6, F6, G6, H6' '100' '0'
#  '17' 'Distributing  AZT 16 MED_A']
# ['labware_5' 'B1' 'labware_3' 'A6, B6, C6, D6, E6, F6, G6, H6' '100' '0'
#  '17' 'Distributing  AZT 16 MED_A']
# ['labware_5' 'B1' 'labware_4' 'A6, B6, C6, D6, E6, F6, G6, H6' '100' '0'
#  '17' 'Distributing  AZT 16 MED_A']
# ['labware_5' 'B2' 'labware_1' 'A5, B5, C5, D5, E5, F5, G5, H5' '100' '0'
#  '18' 'Distributing  AZT 32 MED_A']
# ['labware_5' 'B2' 'labware_2' 'A5, B5, C5, D5, E5, F5, G5, H5' '100' '0'
#  '18' 'Distributing  AZT 32 MED_A']
# ['labware_5' 'B2' 'labware_3' 'A5, B5, C5, D5, E5, F5, G5, H5' '100' '0'
#  '18' 'Distributing  AZT 32 MED_A']
# ['labware_5' 'B2' 'labware_4' 'A5, B5, C5, D5, E5, F5, G5, H5' '100' '0'
#  '18' 'Distributing  AZT 32 MED_A']
# ['labware_5' 'B3' 'labware_1' 'A4, B4, C4, D4, E4, F4, G4, H4' '100' '0'
#  '19' 'Distributing  AZT 64 MED_A']
# ['labware_5' 'B3' 'labware_2' 'A4, B4, C4, D4, E4, F4, G4, H4' '100' '0'
#  '19' 'Distributing  AZT 64 MED_A']
# ['labware_5' 'B3' 'labware_3' 'A4, B4, C4, D4, E4, F4, G4, H4' '100' '0'
#  '19' 'Distributing  AZT 64 MED_A']
# ['labware_5' 'B3' 'labware_4' 'A4, B4, C4, D4, E4, F4, G4, H4' '100' '0'
#  '19' 'Distributing  AZT 64 MED_A']
# ['labware_5' 'B4' 'labware_1' 'A3, B3, C3, D3, E3, F3, G3, H3' '100' '0'
#  '20' 'Distributing  AZT 128 MED_A']
# ['labware_5' 'B4' 'labware_2' 'A3, B3, C3, D3, E3, F3, G3, H3' '100' '0'
#  '20' 'Distributing  AZT 128 MED_A']
# ['labware_5' 'B4' 'labware_3' 'A3, B3, C3, D3, E3, F3, G3, H3' '100' '0'
#  '20' 'Distributing  AZT 128 MED_A']
# ['labware_5' 'B4' 'labware_4' 'A3, B3, C3, D3, E3, F3, G3, H3' '100' '0'
#  '20' 'Distributing  AZT 128 MED_A']
# ['labware_5' 'B5' 'labware_1' 'A2, B2, C2, D2, E2, F2, G2, H2' '100' '0'
#  '21' 'Distributing  AZT 256 MED_A']
# ['labware_5' 'B5' 'labware_2' 'A2, B2, C2, D2, E2, F2, G2, H2' '100' '0'
#  '21' 'Distributing  AZT 256 MED_A']
# ['labware_5' 'B5' 'labware_3' 'A2, B2, C2, D2, E2, F2, G2, H2' '100' '0'
#  '21' 'Distributing  AZT 256 MED_A']
# ['labware_5' 'B5' 'labware_4' 'A2, B2, C2, D2, E2, F2, G2, H2' '100' '0'
#  '21' 'Distributing  AZT 256 MED_A']
# ['labware_6' 'A1' 'labware_1' 'A1, A12, B1, B12, C1, C12, D1, D12' '200'
#  '0' '19' 'Filling outer wells with WATER']
# ['labware_6' 'A1' 'labware_1' 'E1, E12, F1, F12, G1, G12, H1, H12' '200'
#  '0' '20' 'Filling outer wells with WATER']
# ['labware_6' 'A1' 'labware_2' 'A1, A12, B1, B12, C1, C12, D1, D12' '200'
#  '0' '21' 'Filling outer wells with WATER']
# ['labware_6' 'A1' 'labware_2' 'E1, E12, F1, F12, G1, G12, H1, H12' '200'
#  '0' '22' 'Filling outer wells with WATER']
# ['labware_6' 'A1' 'labware_3' 'A1, A12, B1, B12, C1, C12, D1, D12' '200'
#  '0' '23' 'Filling outer wells with WATER']
# ['labware_6' 'A2' 'labware_3' 'E1, E12, F1, F12, G1, G12, H1, H12' '200'
#  '0' '24' 'Filling outer wells with WATER']
# ['labware_6' 'A2' 'labware_4' 'A1, A12, B1, B12, C1, C12, D1, D12' '200'
#  '0' '25' 'Filling outer wells with WATER']
# ['labware_6' 'A2' 'labware_4' 'E1, E12, F1, F12, G1, G12, H1, H12' '200'
#  '0' '26' 'Filling outer wells with WATER']
#
# =====================================================
# SIMULATION COMPLETE -- EVERYTHING SEEMS OKAY (so far)
# =====================================================
# Continue run? (Y/N)n
